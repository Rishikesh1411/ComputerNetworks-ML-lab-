# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##  1 UPLOAD THE DATASET

# %%
df=pd.read_csv("House1.csv",usecols=["No_of_rooms","Area","Price"])

# %%
df.head()
# Out:
#    No_of_rooms   Area  Price
# 0            3  120.0   3600
# 1            4  160.0   4000
# 2            2   60.0   2000
# 3            1    NaN   1000
# 4            3  410.0   7800

# %% [markdown]
# ## 2.PLOT FOR DATASETS

# %%
sns.scatterplot(x="Area",y="Price",data=df)
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %%
sns.barplot(x='Area', y='Price', data=df, hue='No_of_rooms')
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %%
sns.boxplot(x='Area',y='Price',data=df,hue='No_of_rooms')
# Out:
# <Axes: xlabel='Area', ylabel='Price'>

# %% [markdown]
# ## 3 CODE FOR MISSING VALUES

# %%
df['Area'].isnull().sum()
# Out:
# 2

# %% [markdown]
# ## 4 CODE FOR MEAN MEDIAN AND STD

# %%
##MEAN
df[['No_of_rooms','Area','Price']].mean()
# Out:
# No_of_rooms       3.650000
# Area            275.555556
# Price          5020.000000
# dtype: float64

# %%
##MEDIAN
df[['No_of_rooms','Area','Price']].median()
# Out:
# No_of_rooms       3.5
# Area            160.0
# Price          4050.0
# dtype: float64

# %%
## STD
df[['No_of_rooms','Area','Price']].std()
# Out:
# No_of_rooms       1.663066
# Area            215.685561
# Price          2392.224246
# dtype: float64

# %% [markdown]
# ## 5 FULL INFORMATION ABOUT DATASET

# %%
df.describe()
# Out:
#        No_of_rooms        Area        Price
# count    20.000000   18.000000    20.000000
# mean      3.650000  275.555556  5020.000000
# std       1.663066  215.685561  2392.224246
# min       1.000000   60.000000  1000.000000
# 25%       2.750000  122.500000  3750.000000
# 50%       3.500000  160.000000  4050.000000
# 75%       5.000000  500.000000  7800.000000
# max       7.000000  650.000000  8100.000000
